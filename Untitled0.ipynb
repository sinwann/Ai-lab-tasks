# %%
print("hello world")
# Out:
# hello world

# %%
x= input("Enter your name")
print(x)
# Out:
# Enter your namesinwan
# sinwan

# %%
a= input("Enter your name")
b=input("Enter your age")
c=input("Enter your interest")
d= input("Enter yoyur nationality")

print("name:",a)
print("age:",b)
print("interest:",c)
print("nationality",d)
# Out:
# Enter your namesinwan
# Enter your age20
# Enter your interestcars
# Enter yoyur nationalityPak
# name: sinwan
# age: 20
# interest: cars
# nationality Pak

# %%
a= int(input("Enter a number for analysis:"))
if a % 2 == 0:
  print("This number is even")
else:
    print("The number is odd")
# Out:
# Enter a number for analysis:15
# The number is odd

# %%
def check_odd_even(number):
  if number % 2 == 0:
    return "Even"
  else:
    return "Odd"

num = int(input("Enter a number:"))
result = check_odd_even(num)
print(f"The number {num} is {result}.")
# Out:
# Enter a number:25
# The number 25 is Odd.

# %%
def details(a,b,c,d):
  a=input("Enter youyr name:")
  b=input("Enter your age:")
  c=input("Enter your interest:")
  d=input("Enter your nationality:")

details(a,b,c,d)
print("name:",a)
print("age:",b)
print("interest:",c)
print("nationality:",d)
# Out:
# Enter youyr name:Sinwan
# Enter your age:20
# Enter your interest:Pak
# Enter your nationality:Pak
# name: 15
# age: 20
# interest: cars
# nationality: Pak

# %%
for i in range(0,5):
  details(a,b,c,d)
  print("name:",b)
  print("age:",b)
  print("interest:",c)
  print("nationality:",d)
# Out:
# Enter youyr name:Sinwan
# Enter your age:20
# Enter your interest:cars
# Enter your nationality:pak
# name: 20
# age: 20
# interest: cars
# nationality: Pak
# Enter youyr name:sinwan
# Enter your age:20
# Enter your interest:cars
# Enter your nationality:pak
# name: 20
# age: 20
# interest: cars
# nationality: Pak
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-858388360.py in <cell line: 0>()
#       1 for i in range(0,5):
# ----> 2   details(a,b,c,d)
#       3   print("name:",b)
#       4   print("age:",b)
#       5   print("interest:",c)
#
# /tmp/ipython-input-4258471966.py in details(a, b, c, d)
#       1 def details(a,b,c,d):
# ----> 2   a=input("Enter youyr name:")
#       3   b=input("Enter your age:")
#       4   c=input("Enter your interest:")
#       5   d=input("Enter your nationality:")
#
# ...

# %%
for i in range(0,5):
  details(a,b,c,d)
  print("name:",a)
  print("age:",b)
  print("interest:",c)
  print("nationality:",d)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-567200125.py in <cell line: 0>()
#       1 for i in range(0,5):
# ----> 2   details(a,b,c,d)
#       3   print("name:",a)
#       4   print("age:",b)
#       5   print("interest:",c)
#
# /tmp/ipython-input-4258471966.py in details(a, b, c, d)
#       1 def details(a,b,c,d):
# ----> 2   a=input("Enter youyr name:")
#       3   b=input("Enter your age:")
#       4   c=input("Enter your interest:")
#       5   d=input("Enter your nationality:")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...

# %%
num= int(input("Enter a number t print its table:"))
for i in range(1,11):
  print(num," x ",i," = ",num*i)
# Out:
# Enter a number t print its table:2
# 2  x  1  =  2
# 2  x  2  =  4
# 2  x  3  =  6
# 2  x  4  =  8
# 2  x  5  =  10
# 2  x  6  =  12
# 2  x  7  =  14
# 2  x  8  =  16
# 2  x  9  =  18
# 2  x  10  =  20

# %%
def is_prime(number):
  if number <= 1:
    return False
  for i in range(2, int(number**0.5) + 1):
    if number % i == 0:
      return False
  return True

num = int(input("Enter a number:"))
if is_prime(num):
  print(f"The number {num} is prime.")
else:
  print(f"The number {num} is not prime.")
# Out:
# Enter a number:5
# The number 5 is prime.
